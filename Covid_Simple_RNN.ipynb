# %% [markdown]
# implementing the libraries
# ---

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# importing training set

# %%
dataset_train=pd.read_excel("cov19_train.xlsx")
dataset_train.head()
# Out:
#            Lat   1/22/20  1/23/20  ...  12/22/20  12/23/20  12/24/20
# 0  Afghanistan  67709953        0  ...     50013     50190     50433
# 1      Albania    201683        0  ...     53425     53814     54317
# 2      Algeria     16596        0  ...     95659     96069     96549
# 3      Andorra     15218        0  ...      7602      7633      7669
# 4       Angola    178739        0  ...     16686     16802     16931
#
# [5 rows x 339 columns]

# %%
dataset_train=dataset_train.T
dataset_train.head()
# Out:
#                  0        1        2    ...       269       270       271
# Lat      Afghanistan  Albania  Algeria  ...     Yemen    Zambia  Zimbabwe
# 1/22/20     67709953   201683    16596  ...  48516388  27849332  29154857
# 1/23/20            0        0        0  ...         0         0         0
# 1/24/20            0        0        0  ...         0         0         0
# 1/25/20            0        0        0  ...         0         0         0
#
# [5 rows x 272 columns]

# %%
training_set=dataset_train.iloc[1:, 247:248]
training_set.head()
# Out:
#             247
# 1/22/20  352433
# 1/23/20       0
# 1/24/20       0
# 1/25/20       0
# 1/26/20       0

# %%
training_set=dataset_train.iloc[1:, 247:248].values

# %% [markdown]
# Feature Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
sc=MinMaxScaler(feature_range=(0,1))
training_set_scaled=sc.fit_transform(training_set)

# %% [markdown]
# Creating the Data Structure with Time Steps

# %%
x_train=[]
y_train=[]
for i in range (10,338):
  x_train.append(training_set_scaled[i-10:i,0])
  y_train.append(training_set_scaled[i,0])
x_train, y_train = np.array(x_train), np.array(y_train)

# %% [markdown]
# Reshaping

# %%
x_train=np.reshape(x_train, (x_train.shape[0],
                             x_train.shape[1],
                             1))

# %% [markdown]
# Building the RNN

# %% [markdown]
# importing keras libraries and packages

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import SimpleRNN
from keras.layers import Dropout

# %% [markdown]
# initializing RNN

# %%
regressor=Sequential()

# %% [markdown]
# Adding First Layer

# %%
regressor.add(SimpleRNN(units = 8,activation='tanh', 
                        return_sequences = True, 
                        input_shape = (x_train.shape[1], 1)))
regressor.add(Dropout(0.2))

# %% [markdown]
# # Yeni Bölüm

# %% [markdown]
# Adding Second Layer

# %%
regressor.add(SimpleRNN(units = 8,activation='tanh', 
                        return_sequences = True))
regressor.add(Dropout(0.2))

# %%
regressor.add(SimpleRNN(units = 8))  
regressor.add(Dropout(0.2))

# %% [markdown]
# Adding Output Layer

# %%
regressor.add(Dense(units=1))

# %% [markdown]
# Compiling the RNN

# %%
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %% [markdown]
# Fitting the RNN to training set

# %%
regressor.fit(x_train, y_train, batch_size=32, epochs=100)
# Out:
# Epoch 1/100
# 11/11 [==============================] - 2s 7ms/step - loss: 0.6216
# Epoch 2/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2351
# Epoch 3/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1834
# Epoch 4/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2175
# Epoch 5/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1473
# Epoch 6/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.1389
# Epoch 7/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.1321
# Epoch 8/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.1133
# Epoch 9/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0924
# Epoch 10/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1068
# Epoch 11/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.1016
# Epoch 12/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0687
# Epoch 13/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0594
# Epoch 14/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0687
# Epoch 15/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0625
# Epoch 16/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0674
# Epoch 17/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0449
# Epoch 18/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0352
# Epoch 19/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0511
# Epoch 20/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0308
# Epoch 21/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0306
# Epoch 22/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0383
# Epoch 23/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0293
# Epoch 24/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0250
# Epoch 25/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0207
# Epoch 26/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0251
# Epoch 27/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0215
# Epoch 28/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0265
# Epoch 29/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0148
# Epoch 30/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0166
# Epoch 31/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0169
# Epoch 32/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0124
# Epoch 33/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0157
# Epoch 34/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0228
# Epoch 35/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0171
# Epoch 36/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0185
# Epoch 37/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0195
# Epoch 38/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0155
# Epoch 39/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0154
# Epoch 40/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0153
# Epoch 41/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0216
# Epoch 42/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0173
# Epoch 43/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0169
# Epoch 44/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0073
# Epoch 45/100
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0126
# Epoch 46/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0150
# Epoch 47/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0143
# Epoch 48/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0118
# Epoch 49/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0093
# Epoch 50/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0113
# Epoch 51/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0121
# Epoch 52/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0120
# Epoch 53/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0114
# Epoch 54/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0138
# Epoch 55/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0074
# Epoch 56/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0106
# Epoch 57/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0111
# Epoch 58/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0095
# Epoch 59/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0135
# Epoch 60/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0083
# Epoch 61/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0122
# Epoch 62/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0095
# Epoch 63/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0138
# Epoch 64/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0107
# Epoch 65/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0086
# Epoch 66/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0073
# Epoch 67/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0104
# Epoch 68/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0123
# Epoch 69/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0085
# Epoch 70/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0061
# Epoch 71/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0075
# Epoch 72/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0105
# Epoch 73/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0097
# Epoch 74/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0097
# Epoch 75/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0241
# Epoch 76/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0135
# Epoch 77/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0097
# Epoch 78/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0083
# Epoch 79/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0059
# Epoch 80/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0076
# Epoch 81/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0072
# Epoch 82/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0071
# Epoch 83/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0133
# Epoch 84/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0120
# Epoch 85/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0081
# Epoch 86/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0059
# Epoch 87/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0077
# Epoch 88/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0123
# Epoch 89/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0099
# Epoch 90/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0092
# Epoch 91/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0119
# Epoch 92/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0047
# Epoch 93/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0066
# Epoch 94/100
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0149
# Epoch 95/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0125
# Epoch 96/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0095
# Epoch 97/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0062
# Epoch 98/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0065
# Epoch 99/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0112
# Epoch 100/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0039

# %% [markdown]
# Making the Predictions and Visualizing the Results

# %%
dataset_test=pd.read_excel("cov19_test.xlsx")
dataset_test.head()
# Out:
#            Lat  12/25/20  12/26/20  ...  01/03/2020  01/04/2020  01/05/2020
# 0  Afghanistan     50655     50810  ...       51526       51526       53011
# 1      Albania     54827     55380  ...       58991       59438       59623
# 2      Algeria     97007     97441  ...      100159      100408      100645
# 3      Andorra      7699      7756  ...        8166        8192        8249
# 4       Angola     17029     17099  ...       17608       17642       17684
#
# [5 rows x 13 columns]

# %%
dataset_test=dataset_test.T
dataset_test.head()
# Out:
#                   0        1        2    ...    269     270       271
# Lat       Afghanistan  Albania  Algeria  ...  Yemen  Zambia  Zimbabwe
# 12/25/20        50655    54827    97007  ...   2092   19234     12786
# 12/26/20        50810    55380    97441  ...   2092   19571     12880
# 12/27/20        50886    55755    97857  ...   2092   19671     12963
# 12/28/20        51039    56254    98249  ...   2094   19834     13077
#
# [5 rows x 272 columns]

# %%
real_set=dataset_test.iloc[1:, 247:248]
real_set.head()
# Out:
#               247
# 12/25/20  2100712
# 12/26/20  2118255
# 12/27/20  2133373
# 12/28/20  2147578
# 12/29/20  2162775

# %%
real_set=dataset_test.iloc[1:, 247:248].values

# %% [markdown]
# Predicted the next days

# %%
dataset_train.head()
# Out:
#                  0        1        2    ...       269       270       271
# Lat      Afghanistan  Albania  Algeria  ...     Yemen    Zambia  Zimbabwe
# 1/22/20     67709953   201683    16596  ...  48516388  27849332  29154857
# 1/23/20            0        0        0  ...         0         0         0
# 1/24/20            0        0        0  ...         0         0         0
# 1/25/20            0        0        0  ...         0         0         0
#
# [5 rows x 272 columns]

# %%
dataset_test.head()
# Out:
#                   0        1        2    ...    269     270       271
# Lat       Afghanistan  Albania  Algeria  ...  Yemen  Zambia  Zimbabwe
# 12/25/20        50655    54827    97007  ...   2092   19234     12786
# 12/26/20        50810    55380    97441  ...   2092   19571     12880
# 12/27/20        50886    55755    97857  ...   2092   19671     12963
# 12/28/20        51039    56254    98249  ...   2094   19834     13077
#
# [5 rows x 272 columns]

# %%
dataset_total=pd.concat([dataset_train, dataset_test.iloc[1:, :]],axis=0).iloc[1:,247:248]

# %%
dataset_total.rename(columns={dataset_total.columns[0]:"Turkey"},inplace=True)
dataset_total.head()
# Out:
#          Turkey
# 1/22/20  352433
# 1/23/20       0
# 1/24/20       0
# 1/25/20       0
# 1/26/20       0

# %%
inputs=dataset_total[len(dataset_total)-len(dataset_test)-10:].values

# %%
inputs=inputs.reshape(-1,1)
inputs
# Out:
# array([[1836728],
#        [1866345],
#        [1898447],
#        [1928165],
#        [1955680],
#        [1982090],
#        [2004285],
#        [2024601],
#        [2043704],
#        [2062960],
#        [2082610],
#        [2100712],
#        [2118255],
#        [2133373],
#        [2147578],
#        [2162775],
#        [2178580],
#        [2194272],
#        [2208652],
#        [2220855],
#        [2232035],
#        [2241912],
#        [2255607]], dtype=object)

# %%
inputs=sc.transform(inputs)

# %%
x_test=[]
for i in range (10,22):
  x_test.append(inputs[i-10:i,0])
x_test=np.array(x_test)
x_test=np.reshape(x_test,(x_test.shape[0],x_test.shape[1],1))
predicted_set=regressor.predict(x_test)
predicted_set=sc.inverse_transform(predicted_set)
# Out:
# WARNING:tensorflow:8 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f5ada844400> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %% [markdown]
# Visualizing

# %%
plt.plot(real_set, color="red",label="Real Values")
plt.plot(predicted_set, color="blue", label="Predicted Values")
plt.title("Covid - 19 from 23.01.2020 to 05.01.2020")
plt.xlabel("Time")
plt.ylabel("Covid - 19 Values")
plt.legend()
plt.show()
